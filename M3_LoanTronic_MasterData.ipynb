# %% [markdown]
# # Module 3
#
# This notebook performs the merging of survey question and response datasets with employee roster data and performs visualization for anaysis.
#
# > [Merge Question and Response Data](#merge)
#
# > [Score Employee by Measurement](#score)
#
# > [Merge Employee and Roster Data](#roster)
#
# > [Group by Department](#group)
#
# > [Business Insights](#insight)

# %%
import pandas as pd 
import numpy as np 
import plotly
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default='plotly_mimetype+notebook_connected'

# %% [markdown]
# <a name="merge"></a>
# ## Merge Questions and Responses
# Load the following datasets:
# - responses_clean.csv download
# - questions_clean.csv download
#
# Merge the questions and responses Data Frames, using the question id as the join key so that each response matches up with the appropriate measurement in the measurement column.
# Create a new column called “mean” and populate it with the following calculations for each employee:
# - “Engagement”: the mean of questions 1 to 5
# - “Leadership”: the mean of questions 6 to 8
# - “Enablement”: the mean of questions 9 to 11
# - “Alignment”: the mean of questions 12 to 14
# - “Development”: the mean of questions 15 to 17

# %%
# Load clean data from CSV files
r_df = pd.read_csv('responses_clean.csv')
q_df = pd.read_csv('questions_clean.csv')

# Merge datasets
qr_df = r_df.merge(q_df, left_on='question_id', right_on='id').drop(columns='id')
qr_df.head(1)
# Out:
#    employee_id  question_id  answer  score measurement  \
# 0          343            1       4    0.8  engagement
#
#                            question
# 0  I am proud to work for [Company]

# %%
# Compute mean by category and employee
sum_df = qr_df.groupby(['employee_id','measurement'], as_index=False)['score'].mean().rename(columns={'score':'mean'})
sum_df.head()
# Out:
#    employee_id  measurement      mean
# 0            4    alignment  0.933333
# 1            4  development  0.933333
# 2            4   enablement  0.933333
# 3            4   engagement  0.800000
# 4            4   leadership  0.933333

# %% [markdown]
# <a name="score"></a>
# ## Score Each Employee by Measurement
# Use the pivot_table function to transform the Dataframe you just created into a Dataframe with the following columns:
# - Employee_id
#   - Engagement: the mean of questions 1 to 5
#   - Leadership: the mean of questions 6 to 8
#   - Enablement: the mean of questions 9 to 11
#   - Alignment: the mean of questions 12 to 14
#   - Development: the mean of questions 15 to 17
# - Add a column called “overall” and compute the overall satisfaction metric per employee. Note that this metric is the simple unweighted mean of all 5 “measurement” categories.
# - Use plotly to produce a scatter matrix of Employee Survey Measures from the Pivot Table.

# %%
# List of measures
measures = sum_df['measurement'].unique()

# Pivot summarized employee data
pv_df = sum_df.pivot(index='employee_id',columns='measurement',values='mean')
pv_df['overall'] = pv_df.mean(axis=1)
pv_df.head()
# Out:
# measurement  alignment  development  enablement  engagement  leadership  \
# employee_id
# 4             0.933333     0.933333    0.933333        0.80    0.933333
# 7             0.866667     0.933333    1.000000        0.92    0.933333
# 10            0.933333     0.800000    0.933333        0.88    1.000000
# 11            0.933333     0.866667    1.000000        0.84    1.000000
# 14            0.866667     0.733333    1.000000        0.80    0.933333
#
# measurement   overall
# employee_id
# 4            0.906667
# 7            0.930667
# 10           0.909333
# 11           0.928000
# 14           0.866667

# %%
# Scatter matrix to review correlations
px.scatter_matrix(data_frame=pv_df, dimensions=measures, 
                title='Correlation Comparison of Survey Measures')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="889f9838-d305-4980-a9f6-043c3baa5453" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("889f9838-d305-4980-a9f6-043c3baa5453")) {                    Plotly.newPlot(                        "889f9838-d305-4980-a9f6-043c3baa5453",                        [{"dimensions": [{"axis": {"matches": true}, "label": "alignment", "values": [0.9333333333333332, 0.8666666666666667, 0.9333333333333332, 0.9333333333333332, 0.8666666666666667, 1.0, 1.0, 0.9333333333333332, 0.9333333333333332, 0.8666666666666667, 0.9333333333333332, 0.9333333333333332, 0.7999999999999999, 0.8000000000000002, 0.9333333333333332, 0.8666666666666667, 0.9333333333333332, 1.0, 0.7999999999999999, 1.0, 0.8666666666666667, 1.0, 0.9333333333333332, 0.9333333333333332, 1.0, 0.8666666666666667, 0.8666666666666667, 0.8666666666666667, 0.8666666666666667, 0.8666666666666667, 0.8666666666666667, 0
mst_df = pv_df.merge(e_df, on='employee_id')
mst_df.head()
# Out:
#    employee_id  alignment  development  enablement  engagement  leadership  \
# 0            4   0.933333     0.933333    0.933333        0.80    0.933333
# 1            7   0.866667     0.933333    1.000000        0.92    0.933333
# 2           10   0.933333     0.800000    0.933333        0.88    1.000000
# 3           11   0.933333     0.866667    1.000000        0.84    1.000000
# 4           14   0.866667     0.733333    1.000000        0.80    0.933333
#
#     overall               title    last       first  ...         function  \
# 0  0.906667  Senior Underwriter  Deleon   Josephine  ...  Finance & Admin
# 1  0.930667  Senior Underwriter  Bailey  Kristopher  ...  Finance & Admin
# 2  0.909333        Loan Officer   Scott        Iris  ...  Loan Operations
# 3  0.928000      VP Engineering   Xiong      Steven  ...              CEO
# 4  0.866667            Engineer  Nguyen       Terri  ...      Engineering
#
#            department           location      age sex ethnicity  \
# 0        Underwriting  Mountain View, CA  25 - 34   F     asian
# 1        Underwriting  Mountain View, CA  25 - 34   M     asian
# 2  East Coast Lending       New York, NY  18 - 24   F     white
# 3         Engineering  Mountain View, CA  35 - 44   M     asian
# 4            Back End  Mountain View, CA  45 - 54   F     asian
#
#   employment_status                  tenure count  tenure_id
# 0         Full time  4 to less than 6 years     1          4
# 1         Full time  4 to less than 6 years     1          4
# 2         Full time  4 to less than 6 years     1          4
# 3         Full time  4 to less than 6 years     1          4
# 4         Full time  4 to less than 6 years     1          4
#
# [5 rows x 21 columns]

# %%
# Save master datasets
mst_df.to_csv('roster_with_score.csv')

# %% [markdown]
# <a name="group"></a>
# ## Group by Department Names:
# Use the merged dataset to compute the mean overall satisfaction by department. Perform the following tasks:
# - Compute the mean overall satisfaction by department.
# - Produce a Box plot to visualize the overall results with respect to each categorical variable of the roster:
#   - `categories = ['function', 'department','location', 'ethnicity','employment_status','tenure','sex']`
# - Inspect the data and provide your observations as to which categorical variables are most likely to impact employee satisfaction.

# %%
# Mean satisfaction by department
dp_df = mst_df.groupby('department', as_index=False)['overall'].mean()
dp_df.head()
# Out:
#               department   overall
# 0    Advanced Technology  0.762667
# 1  Algorithm Development  0.790377
# 2               Back End  0.750175
# 3      Channel Marketing  0.739333
# 4             Compliance  0.783515

# %%
# Save department summary
dp_df.to_csv('responses_clean_with_dept.csv')

# %%
categories = ['function', 'department','location', 'ethnicity','employment_status','tenure','sex']
fig = plotly.subplots.make_subplots(rows=3,cols=3,specs=[[{'type':'box'} for x in range(0,3)] for y in range(0,3)])

for i, cat in enumerate(categories):
    fig.add_trace(go.Box(x=mst_df[cat], y=mst_df.overall), col=i % 3 + 1, row=i//3+1)
fig.update_layout(title='Reponse Distributions across Categories',height=700,width=1300,showlegend=False)
fig.show()
# Out:
# <div>                            <div id="d95edc35-0e26-4265-906c-5a4c4cf64bac" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d95edc35-0e26-4265-906c-5a4c4cf64bac")) {                    Plotly.newPlot(                        "d95edc35-0e26-4265-906c-5a4c4cf64bac",                        [{"type": "box", "x": ["Finance & Admin", "Finance & Admin", "Loan Operations", "CEO", "Engineering", "Engineering", "CEO", "Engineering", "Engineering", "Finance & Admin", "Engineering", "Product", "Marketing", "Compliance", "Engineering", "Finance & Admin", "CEO", "Engineering", "Loan Operations", "Loan Operations", "Product", "Engineering", "Engineering", "Product", "Engineering", "Product", "Loan Operations", "Engineering", "Finance & Admin", "Engineering", "CEO", "Loan Operations", "Loan Operations", "Engineering", "Engineering", "Marketing", "CEO", "Product", "Product", "Finance & Admin", "Loan Operations", "Product", "Engineering", "Finance & Admin", "Loan Operations", "Engineering", "Finance & Admin", "Engineering", "Loan Operations", "Finance & Admin", "Finance & Admin", "Advanced Technology", "Engineering", "Engineering", "Finance & Admin", "Engineering", "Engineering", "Advanced Technology", "Engineering", "Engineering", "Finance & Admin", "Finance & Admin", "Loan Operations", "Loan Operations", "Finance & Admin", "Compliance", "Loan Operations", "Loan Operations", "Engineering", "Loan Operations", "Compliance", "Loan Operations", "Engineering", "Engineering", "Finance & Admin", "Loan Operations", "Finance & Admin", "Product", "Finance & Admin", "Engineering", "Engineering", "Finance & Admin", "Engineering", "Finance & Admin", "Loan Operations", "Product", "Engineering", "Finance & Admin", "Product", "Engineering", "Finance & Admin", "Engineering", "Loan Operations", "Loan Operations", "CEO", "Engineering", "Finance & Admin", "Engineering", "Engineering", "Product", "Engineering", "Engineering", "Product", "Finance & Admin", "Loan Operations", "Product", "Loan Operations", "CEO", "Engineering", "Compliance", "Loan Operations", "Product", "Loan Operations", "Loan Operations", "Loan Operations", "Engineering", "Engineering", "Product", "Loan Operations", "Advanced Technology", "Engineering", "Product", "Compliance", "Loan Operations", "Engineering", "CEO", "Product", "Product", "Finance & Admin", "Finance & Admin", "Loan Operations", "Engineering", "Finance & Admin", "Loan Operations", "Finance & Admin", "Compliance", "Product", "Engineering", "Finance & Admin", "Product", "Engineering", "Engineering", "Finance & Admin", "Engineering", "Finance & Admin", "Finance & Admin", "Loan Operations", "Loan Operations", "Engineering", "Finance & Admin", "Loan Operations", "Engineering", "Engineering", "Engineering", "Finance & Admin", "Engineering", "Loan Operations", "Engineering", "Finance & Admin", "Engineering", "Loan Operations", "Engineering", "Finance & Admin", "Marketing", "Engineering", "CEO", "Engineering", "Product", "Engineering", "Engineering", "Finance & Admin", "Engineering", "Compliance", "Loan Operations", "Engineering", "Engineering", "Engineering", "Loan Operations", "Finance & Admin", "Product", "Loan Operations", "Engineering", "Loan Operations", "Loan Operations", "Marketing", "Engineering", "Engineering", "CEO", "Engineering", "Engineering", "Loan Operations", "Loan Operations", "Engineering", "Engineering", "Marketing", "Product", "Engineering", "Engineering", "Engineering", "CEO", "Engineering", "Engineering", "Engineering", "Engineering", "Product", "Finance & Admin", "Product", "Finance & Admin", "Engineering", "Finance & Admin", "Loan Operations", "Engineering", "Finance & Admin", "Engineering", "Engineering", "Engineering", "Loan Operations", "Engineering", "Loan Operations", " ...

# %% [markdown]
# ### Boxplot Analysis
# Based on the plots generated, the variables that appear to contribute the most to differences in employee satisfaction are `department, ethnicity and tenure`. Employees working in specific departments and at the company over 4 years report higher satisfaction, while people of color report lower satisfaction.

# %% [markdown]
# <a name="insight"></a>
# ## Business Insights:
# What business insights can you draw from looking at the data? Are there noticeable differences between categories? Be sure to support your observations with your data analysis. Which functional groups seem most satisfied? Which ones seem least satisfied?
# - Are some locations more satisfied than others?
# - Do you have reason to believe that tenure relates to overall satisfaction?
# - Out of sex and ethnicity which seems most related to overall satisfaction?

# %% [markdown]
# ### Insight Responses
# - Satisfaction appears to be the highest in Mountain View and New York, while Atlanta and Chicago report notably lower satisfaction
# - After 1 year, it does appear that each increased tenure category reports higher levels of job satisfaction than the previous group
# - Ethnicity appears to have a more significant impact on satistfaction, with people of color reporting significantly lower satisfaction, while gender only shows small differences

# %%
# !jupyter nbconvert --to html --template full LoanTronic_MasterData.ipynb
# Out:
# [NbConvertApp] Converting notebook LoanTronic_MasterData.ipynb to html
# [NbConvertApp] Writing 444704 bytes to LoanTronic_MasterData.html
